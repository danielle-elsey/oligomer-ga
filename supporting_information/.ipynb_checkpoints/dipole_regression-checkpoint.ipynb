# %% [markdown]
# # Dipole Regression

# %% [markdown]
# ### Imports

# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import HuberRegressor, LinearRegression
import matplotlib.pyplot as plt
from sklearn.metrics import mean_absolute_error

# %% [markdown]
# ### Data Processing

# %% [markdown]
# Load & Proccess Data

# %%
master = pd.read_csv('dipole_master.csv')

# %% [markdown]
# ### Method Definition

# %%
'''
    Calculates root mean square error

    Parameters
    ---------
    predictions: ndarray of floats
        expected values [based on best fit line]
    observations: ndarray of floats
        observed values
    
    Returns
    -------
    rmse: float
        root mean square error
'''
def calc_rmse(predictions, observations):
    rmse = np.sqrt(((predictions - observations) ** 2).mean())
    return rmse

# %%
'''
    Performs Huber linear regression on data set and calculates associated values [ROBUST TO OUTLIERS]

    Parameters
    ---------
    x: ndarray of floats
        x values
    y: ndarray of floats
        y values
    intercept: boolean
        if true, calculates y intercept, if false sets y intercept to 0 (forces fit)
    
    Returns
    -------
    lin_regress_var: list of floats
        slope, y-intercept, r^2, root mean square error
'''
def perform_huber_regress(x, y, intercept=True):
    
    # 2D X array necessary for sklearn
    xi = x.reshape((-1,1))
    
    model = HuberRegressor(fit_intercept=intercept)
    model.fit(xi, y)
    
    slope = model.coef_[0]
    intercept = model.intercept_
    r_squared = model.score(xi, y)
    
    # calculate RMSE
    y_pred = y
    y_true = []
    for val in x: 
        y_tr = slope*val + intercept
        y_true.append(y_tr)
    y_true = np.array(y_true)

    rmse = calc_rmse(y_pred, y_true)
    
    huber_regress_var = [slope, intercept, r_squared, rmse]
    
    return huber_regress_var

# %%
# matplotlib global formatting

SMALL_SIZE = 10
MEDIUM_SIZE = 12
BIGGER_SIZE = 14

plt.rc('font', size=SMALL_SIZE)          # controls default text sizes
plt.rc('axes', titlesize=SMALL_SIZE)     # fontsize of the axes title
plt.rc('axes', labelsize=MEDIUM_SIZE)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=MEDIUM_SIZE)    # fontsize of the tick labels
plt.rc('ytick', labelsize=MEDIUM_SIZE)    # fontsize of the tick labels
plt.rc('legend', fontsize=SMALL_SIZE)    # legend fontsize
plt.rc('figure', titlesize=MEDIUM_SIZE)  # fontsize of the figure title

plt.rcParams['figure.dpi'] = 300

# %% [markdown]
# ### Calculate MAE

# %% [markdown]
# MAE for 0-50 A^3

# %%
# slice out data
zero_df = master[master['gfn2_dipole(Debye)'] <= 50]

x=zero_df['gfn2_dipole(Debye)'].values
y=zero_df['dipole(Debye)'].values

# perform Huber regression
slope, intercept, r_squared, rmserror = perform_huber_regress(x, y, False)

zero_copy = zero_df.copy()
zero_copy['huber'] = zero_copy['gfn2_dipole(Debye)']*slope
zero_copy.tail()
# Out:
#                          ID  dipole(Debye)  gfn2_dipole(Debye)  polar(A^3)  \
# 68                   pyrene        0.00000               0.000         NaN
# 69     dibenzo-bi-phenazine        0.00000               0.000         NaN
# 70  3E5E-octa-1357-tetraene        0.00002               0.000         NaN
# 71           benzo-a-pyrene        0.01627               0.029         NaN
# 72     dibenzo-ai-phenazine        0.60834               0.580         NaN
#
#     gfn2_polar(A^3)     huber
# 68              NaN  0.000000
# 69              NaN  0.000000
# 70              NaN  0.000000
# 71              NaN  0.024702
# 72              NaN  0.494046

# %%
# MAE wb97X(D) vs linear-fit GFN2
mae_zero=mean_absolute_error(zero_copy['dipole(Debye)'], zero_copy['huber'])
mae_zero
# Out:
# 3.662852304506901

# %% [markdown]
# MAE for all data

# %%
x = master['gfn2_dipole(Debye)'].values
y = master['dipole(Debye)'].values

# perform Huber regression
slope, intercept, r_squared, rmserror = perform_huber_regress(x, y, False)

master_copy = master.copy()
master_copy['huber'] = master_copy['gfn2_dipole(Debye)']*slope
master_copy.tail()
# Out:
#                          ID  dipole(Debye)  gfn2_dipole(Debye)  polar(A^3)  \
# 70  3E5E-octa-1357-tetraene        0.00002               0.000         NaN
# 71           benzo-a-pyrene        0.01627               0.029         NaN
# 72     dibenzo-ai-phenazine        0.60834               0.580         NaN
# 73          364_1073_110000      206.68977             142.597     520.698
# 74          1073_690_001111      182.84001             142.453     743.582
#
#     gfn2_polar(A^3)       huber
# 70              NaN    0.000000
# 71              NaN    0.028010
# 72              NaN    0.560193
# 73          152.236  137.727205
# 74          170.534  137.588123

# %%
# MAE wb97X(D) vs linear-fit GFN2
mae=mean_absolute_error(master_copy['dipole(Debye)'], master_copy['huber'])
mae
# Out:
# 5.319426060031343

# %% [markdown]
# ### Plot

# %%
# set up subplot figure
fig, axs = plt.subplots(1, 2)
top = 0.5
bottom = 0
left = 0
right = 1
plt.subplots_adjust(top=top, bottom=bottom, left=left, right=right, wspace=0.25)


# SUBPLOT 0: 0-50 Å³
# slice out data
zero_df = master[master['gfn2_dipole(Debye)'] <= 50]

x=zero_df['gfn2_dipole(Debye)'].values
y=zero_df['dipole(Debye)'].values

axs[0].set(ylim=(-2,60), xlim=(-2,60))
axs[0].set_xlabel('GFN2 µ(Debye)')
axs[0].set_ylabel('ωB97X cc-pVTZ µ(Debye)')

# perform linear regression
slope, intercept, r_squared, rmserror = perform_huber_regress(x, y, False)

# plot points & regression line
axs[0].scatter(x, y, s=5, c='#003f5c')
axs[0].plot(x, slope*x+intercept, c='#ffa600')

# print regression line equation & r-squared
if intercept < 0:
    y_int = '- %.3f' % abs(intercept)
else: 
    y_int = '+ %.3f' % intercept
axs[0].text(-1, 45, 'y = %.3f x %s\nR²=%.2f\nMAE=%.2f Debye' % (slope, y_int, r_squared, mae_zero))


# SUBPLOT 1: All Data
x = master['gfn2_dipole(Debye)'].values
y = master['dipole(Debye)'].values

axs[1].set(ylim=(-10,225), xlim=(-10,225))
axs[1].set_xlabel('GFN2 µ(Debye)')

# perform linear regression
slope, intercept, r_squared, rmserror = perform_huber_regress(x, y, False)

# plot points & regression line
axs[1].scatter(x, y, s=5, c='#003f5c')
axs[1].plot(x, slope*x+intercept, c='#ffa600')

# print regression line equation & r-squared
if intercept < 0:
    y_int = '- %.3f' % abs(intercept)
else: 
    y_int = '+ %.3f' % intercept
axs[1].text(-5, 168, 'y = %.3f x %s\nR²=%.2f\nMAE=%.2f Debye' % (slope, y_int, r_squared, mae))

plt.savefig('dipole_regression.png', transparent=False, bbox_inches='tight')
plt.show()
